# %% [markdown]
# ## Import Needed Libraries

# %%
from bs4 import BeautifulSoup
import requests
import time, os
from selenium.webdriver.common.keys import Keys
from functools import reduce, partial
#libraries for data and modeling
import numpy as np
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

driver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = driver

# %%
#function to randomize sleep times to help spoof activity
def human_imposter(n = 60):
    i = round(np.random.uniform(low=15,high=n),3)
    time.sleep(i)

# %%
driver=webdriver.Chrome(driver)
driver.get('https://www.formula1.com/en/results.html/2021/races/1064/bahrain/race-result.html' )
print('You have 1 minute to manually pass the cookies popup')
time.sleep(60)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1310             try:
# -> 1311                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1312                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-4-8cf71355833e> in <module>
# ----> 1 driver=webdriver.Chrome(driver)
#       2 driver.get('https://www.formula1.com/en/results.html/2021/races/1064/bahrain/race-result.html' )
#       3 print('You have 1 minute to manually pass the cookies popup')
#       4 time.sleep(60)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      79         except OSError as err:
#      80             if err.errno == errno.ENOENT:
# ---> 81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
#      83                         os.path.basename(self.path), self.start_error_message)
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home

# %% [markdown]
# ## Web scrapping

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %% [markdown]
# ### Exctract Records of Each Menu

# %%
str_records = ["_".join(i.text.split()) for i in soup.find_all('a',{'data-name':'resultType'})]
str_records
# Out:
# ['Race_result',
#  'Fastest_laps',
#  'Pit_stop_summary',
#  'Starting_grid',
#  'Qualifying',
#  'Practice_3',
#  'Practice_2',
#  'Practice_1']

# %%
str_locations = [i.findNext().text for i in soup.find_all('a',{'data-name':'meetingKey'})[1:]]
str_locations
# Out:
# ['Bahrain',
#  'Emilia Romagna',
#  'Portugal',
#  'Spain',
#  'Monaco',
#  'Azerbaijan',
#  'France',
#  'Styria',
#  'Austria',
#  'Great Britain',
#  'Hungary',
#  'Belgium',
#  'Netherlands',
#  'Italy',
#  'Russia',
#  'Turkey',
#  'United States ',
#  'Mexico',
#  'Brazil',
#  'Qatar',
#  'Saudi Arabia',
#  'Abu Dhabi']

# %%
str_years = [i.findNext().text for i in soup.find_all('a',{'data-name':'year'})]
str_years[:12]
# Out:
# ['2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010']

# %%
years = driver.find_elements_by_xpath('//a[@data-name="year"]')

# %%
locations = driver.find_elements_by_xpath('//a[@data-name="meetingKey"]')

# %%
records = driver.find_elements_by_xpath('//a[@data-name="resultType"]')

# %% [markdown]
# ### Function to Get Data from the Table

# %%
def get_table_data(record):    
    temp_soup = BeautifulSoup(driver.page_source, 'html.parser')
    table = temp_soup.find('table')
    rows = [row for row in table.find_all('tr')] 
    my_list = []
    headers = ['_'.join(i.text.strip().split()) for i in rows[0].find_all('th')[1:-1]]
    headers = [(record+'_'+header)  if header!='Driver' else header for header in headers]
    for row in rows[1:]:
        temp_row = [ ' '.join(j.text.strip().split()) for j in row.find_all('td')[1:-1]]  
        my_list.append(dict(zip(headers,temp_row)))

    return(pd.DataFrame(my_list))

# %%
# Function to scrap the data from location menu
def get_records_df(location):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    if (str_records != ["_".join(i.text.split()) for i in soup.find_all('a',{'data-name':'resultType'})]):
        return None
    my_dict = {}
    for i, record in enumerate(str_records):
        records = driver.find_elements_by_xpath('//a[@data-name="resultType"]')
        records[i].click()
        human_imposter(15) #need time for loading tables
        my_dict[record] = get_table_data(record)

    my_reduce = partial(pd.merge, on='Driver', how='outer') 
    temp = reduce(my_reduce, my_dict.values())
    temp['location'] = location
    return temp

# %%
# Function to scrap the data from year menu
def get_loc_df(year):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    str_locations = [i.findNext().text for i in soup.find_all('a',{'data-name':'meetingKey'})[1:]]
    my_dict = {}
    for i, location in enumerate(str_locations):
        locations = driver.find_elements_by_xpath('//a[@data-name="meetingKey"]')
        driver.execute_script("window.scrollTo(0, 0);"); #can't click unless you scroll up all the way
        time.sleep(3) #allow time for scroll
        locations[i+1].click() #need +1 to avoid All category
        human_imposter(15)
        temp_df = get_records_df(location)
        if temp_df is None:
            continue #iterate past races without standard records
        my_dict[location] = temp_df
    temp = pd.concat(my_dict.values(),ignore_index = True)
    temp['year'] = year
    return temp

# %% [markdown]
# ## Merge Each four years together

# %% [markdown]
# - we did not merge all data at once to avoid issues caused by big data

# %%
my_dict = {}
for i, year in enumerate(str_years[0:4]):
    years = driver.find_elements_by_xpath('//a[@data-name="year"]')
    driver.execute_script("window.scrollTo(0, 0);"); #can't click unless you scroll up all the way
    time.sleep(3) #allow time for scroll
    years[i].click()
    human_imposter(15)
    my_dict[year] = get_loc_df(year)
df = pd.concat(my_dict.values(),ignore_index = True)
df
# Out:
#      Race_result_Pos Race_result_No                  Driver  \
# 0                  1             44      Lewis Hamilton HAM
# 1                  1             44      Lewis Hamilton HAM
# 2                  2             33      Max Verstappen VER
# 3                  2             33      Max Verstappen VER
# 4                  3             77     Valtteri Bottas BOT
# ...              ...            ...                     ...
# 2239              NC              9     Marcus Ericsson ERI
# 2240              NC              7      Kimi Räikkönen RAI
# 2241              NC             27     Nico Hulkenberg HUL
# 2242             NaN            NaN  Antonio Giovinazzi GIO
# 2243             NaN            NaN       Robert Kubica KUB
#
#             Race_result_Car Race_result_Laps Race_result_Time/Retired  \
# 0                  Mercedes               56              1:32:03.897
# 1                  Mercedes               56              1:32:03.897
# 2     Red Bull Racing Honda               56                  +0.745s
# 3     Red Bull Racing Honda               56                  +0.745s
# 4                  Mercedes               56                 +37.383s
# ...                     ...              ...                      ...
# 2239         Sauber Ferrari               24                      DNF
# 2240                Ferrari                6                      DNF
# 2241                Renault                0                      DNF
# 2242                    NaN              NaN                      NaN
# 2243                    NaN              NaN                      NaN
#
#      Race_result_PTS Fastest_laps_Pos Fastest_laps_No       Fastest_laps_Car  \
# 0                 25                4              44               Mercedes
# 1                 25                4              44               Mercedes
# 2                 18                2              33  Red Bull Racing Honda
# 3                 18                2              33  Red Bull Racing Honda
# 4                 16                1              77               Mercedes
# ...              ...              ...             ...                    ...
# 2239               0               19               9         Sauber Ferrari
# 2240               0               18               7                Ferrari
# 2241               0              NaN             NaN                    NaN
# 2242             NaN              NaN             NaN                    NaN
# 2243             NaN              NaN             NaN                    NaN
#
#       ... Practice_2_Gap Practice_2_Laps Practice_1_Pos Practice_1_No  \
# 0     ...        +0.235s              24              4            44
# 1     ...        +0.235s              24              4            44
# 2     ...                             23              1            33
# 3     ...                             23              1            33
# 4     ...        +0.371s              23              2            77
# ...   ...            ...             ...            ...           ...
# 2239  ...        +2.266s              36             17             9
# 2240  ...        +0.225s              40              7             7
# 2241  ...        +0.994s              36             12            27
# 2242  ...            NaN             NaN             16            36
# 2243  ...            NaN             NaN             20            40
#
#              Practice_1_Car Practice_1_Time Practice_1_Gap Practice_1_Laps  \
# 0                  Mercedes        1:31.921        +0.527s              15
# 1                  Mercedes        1:31.921        +0.527s              15
# 2     Red Bull Racing Honda        1:31.394                             12
# 3     Red Bull Racing Honda        1:31.394                             12
# 4                  Mercedes        1:31.692        +0.298s              17
# ...                     ...             ...            ...             ...
# 2239         Sauber Ferrari        1:41.928        +3.437s              22
# 2240                Ferrari        1:40.417        +1.926s              24
# 2241                Renault        1:41.023        +2.532s              24
# 2242         Sauber Ferrari        1:41.662        +3.171s              24
# 2243      Williams Mercedes        1:42.992        +4.501s              26
#
#        location  year
# 0       Bahrain  2021
# 1       Bahrain  2021
# 2       Bahrain  2021
# 3       Bahrain  2021
# 4       Bahrain  2021
# ...         ...   ...
# 2239  Abu Dhabi  2018
# 2240  Abu Dhabi  2018
# 2241  Abu Dhabi  2018
# 2242  Abu Dhabi  2018
# 2243  Abu Dhabi  2018
#
# [2244 rows x 52 columns]

# %%
my_dict = {}
for i, year in enumerate(str_years[4:8]):
    years = driver.find_elements_by_xpath('//a[@data-name="year"]')
    driver.execute_script("window.scrollTo(0, 0);"); #can't click unless you scroll up all the way
    time.sleep(3) #allow time for scroll
    years[i+4].click()
    human_imposter(15)
    my_dict[year] = get_loc_df(year)
df2 = pd.concat(my_dict.values(),ignore_index = True)
df2
# Out:
#      Race_result_Pos Race_result_No                Driver  \
# 0                  1              5  Sebastian Vettel VET
# 1                  2             44    Lewis Hamilton HAM
# 2                  3             77   Valtteri Bottas BOT
# 3                  4              7    Kimi Räikkönen RAI
# 4                  5             33    Max Verstappen VER
# ...              ...            ...                   ...
# 3284              NC             10   Kamui Kobayashi KOB
# 3285              NC             13  Pastor Maldonado MAL
# 3286              NC             26      Daniil Kvyat KVY
# 3287             NaN            NaN      Esteban Ocon OCO
# 3288             NaN            NaN      Adderly Fong FON
#
#                 Race_result_Car Race_result_Laps Race_result_Time/Retired  \
# 0                       Ferrari               57              1:24:11.672
# 1                      Mercedes               57                  +9.975s
# 2                      Mercedes               57                 +11.250s
# 3                       Ferrari               57                 +22.393s
# 4     Red Bull Racing TAG Heuer               57                 +28.827s
# ...                         ...              ...                      ...
# 3284           Caterham Renault               42                      DNF
# 3285              Lotus Renault               26                      DNF
# 3286                STR Renault               14                      DNF
# 3287                        NaN              NaN                      NaN
# 3288                        NaN              NaN                      NaN
#
#      Race_result_PTS Fastest_laps_Pos Fastest_laps_No  \
# 0                 25                3               5
# 1                 18                6              44
# 2                 15                2              77
# 3                 12                1               7
# 4                 10                5              33
# ...              ...              ...             ...
# 3284               0               13              10
# 3285               0               20              13
# 3286               0               19              26
# 3287             NaN              NaN             NaN
# 3288             NaN              NaN             NaN
#
#                Fastest_laps_Car  ... Practice_1_Pos Practice_1_No  \
# 0                       Ferrari  ...              6             5
# 1                      Mercedes  ...              1            44
# 2                      Mercedes  ...              2            77
# 3                       Ferrari  ...              5             7
# 4     Red Bull Racing TAG Heuer  ...              4            33
# ...                         ...  ...            ...           ...
# 3284           Caterham Renault  ...             18            10
# 3285              Lotus Renault  ...             15            13
# 3286                STR Renault  ...              7            26
# 3287                        NaN  ...             16            31
# 3288                        NaN  ...             19            37
#
#                  Practice_1_Car Practice_1_Time Practice_1_Gap  \
# 0                       Ferrari        1:25.464        +1.244s
# 1                      Mercedes        1:24.220
# 2                      Mercedes        1:24.803        +0.583s
# 3                       Ferrari        1:25.372        +1.152s
# 4     Red Bull Racing TAG Heuer        1:25.246        +1.026s
# ...                         ...             ...            ...
# 3284           Caterham Renault        1:47.971        +4.495s
# 3285              Lotus Renault        1:46.711        +3.235s
# 3286                STR Renault        1:45.835        +2.359s
# 3287              Lotus Renault        1:47.066        +3.590s
# 3288             Sauber Ferrari        1:48.269        +4.793s
#
#      Practice_1_Laps   location  year Pit_stop_summary_Pos  \
# 0                 10  Australia  2017                  NaN
# 1                 22  Australia  2017                  NaN
# 2                 25  Australia  2017                  NaN
# 3                 16  Australia  2017                  NaN
# 4                 19  Australia  2017                  NaN
# ...              ...        ...   ...                  ...
# 3284              24  Abu Dhabi  2014                  NaN
# 3285              31  Abu Dhabi  2014                  NaN
# 3286              32  Abu Dhabi  2014                  NaN
# 3287              29  Abu Dhabi  2014                  NaN
# 3288              25  Abu Dhabi  2014                  NaN
#
#      Pit_stop_summary_Avg_Speed
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3284                        NaN
# 3285                        NaN
# 3286                        NaN
# 3287                        NaN
# 3288                        NaN
#
# [3289 rows x 54 columns]

# %%
my_dict = {}
for i, year in enumerate(str_years[8:12]):
    years = driver.find_elements_by_xpath('//a[@data-name="year"]')
    driver.execute_script("window.scrollTo(0, 0);"); #can't click unless you scroll up all the way
    time.sleep(3) #allow time for scroll
    years[i+8].click()
    human_imposter(15)
    my_dict[year] = get_loc_df(year)
df3 = pd.concat(my_dict.values(),ignore_index = True)
df3
# Out:
#      Race_result_Pos Race_result_No                  Driver  \
# 0                  1              7      Kimi Räikkönen RAI
# 1                  1              7      Kimi Räikkönen RAI
# 2                  2              3     Fernando Alonso ALO
# 3                  2              3     Fernando Alonso ALO
# 4                  2              3     Fernando Alonso ALO
# ...              ...            ...                     ...
# 3875              21             18        Jarno Trulli TRU
# 3876              NC             24          Timo Glock GLO
# 3877              NC              3  Michael Schumacher MSC
# 3878              NC             15   Vitantonio Liuzzi LIU
# 3879             NaN            NaN        Fairuz Fauzy FAU
#
#            Race_result_Car Race_result_Laps Race_result_Time/Retired  \
# 0            Lotus Renault               58              1:30:03.225
# 1            Lotus Renault               58              1:30:03.225
# 2                  Ferrari               58                 +12.451s
# 3                  Ferrari               58                 +12.451s
# 4                  Ferrari               58                 +12.451s
# ...                    ...              ...                      ...
# 3875        Lotus Cosworth               51                  +4 laps
# 3876       Virgin Cosworth               43                      DNF
# 3877              Mercedes                0                      DNF
# 3878  Force India Mercedes                0                      DNF
# 3879                   NaN              NaN                      NaN
#
#      Race_result_PTS Fastest_laps_Pos Fastest_laps_No Fastest_laps_Car  ...  \
# 0                 25                1               7    Lotus Renault  ...
# 1                 25                1               7    Lotus Renault  ...
# 2                 18                3               3          Ferrari  ...
# 3                 18                3               3          Ferrari  ...
# 4                 18                3               3          Ferrari  ...
# ...              ...              ...             ...              ...  ...
# 3875               0               18              18   Lotus Cosworth  ...
# 3876               0               22              24  Virgin Cosworth  ...
# 3877               0              NaN             NaN              NaN  ...
# 3878               0              NaN             NaN              NaN  ...
# 3879             NaN              NaN             NaN              NaN  ...
#
#      Practice_2_Gap Practice_2_Laps Practice_1_Pos Practice_1_No  \
# 0           +0.453s              38              6             7
# 1           +0.453s              38              6             7
# 2           +0.840s              35              3             3
# 3           +0.840s              35              3             3
# 4           +0.840s              35              3             3
# ...             ...             ...            ...           ...
# 3875        +4.724s              35             20            18
# 3876        +4.371s              31             19            24
# 3877        +1.358s              29              7             3
# 3878        +1.315s              31             15            15
# 3879            NaN             NaN             24            19
#
#             Practice_1_Car Practice_1_Time Practice_1_Gap Practice_1_Laps  \
# 0            Lotus Renault        1:27.877        +0.666s              17
# 1            Lotus Renault        1:27.877        +0.666s              17
# 2                  Ferrari        1:27.547        +0.336s              16
# 3                  Ferrari        1:27.547        +0.336s              16
# 4                  Ferrari        1:27.547        +0.336s              16
# ...                    ...             ...            ...             ...
# 3875        Lotus Cosworth        1:48.472        +5.712s              17
# 3876       Virgin Cosworth        1:48.450        +5.690s              19
# 3877              Mercedes        1:44.199        +1.439s              19
# 3878  Force India Mercedes        1:45.585        +2.825s              14
# 3879        Lotus Cosworth        1:51.705        +8.945s              18
#
#        location  year
# 0     Australia  2013
# 1     Australia  2013
# 2     Australia  2013
# 3     Australia  2013
# 4     Australia  2013
# ...         ...   ...
# 3875  Abu Dhabi  2010
# 3876  Abu Dhabi  2010
# 3877  Abu Dhabi  2010
# 3878  Abu Dhabi  2010
# 3879  Abu Dhabi  2010
#
# [3880 rows x 51 columns]

# %% [markdown]
# ## Save all dataframes in csv files for later use

# %%
df.to_csv('2018_2021.csv')

# %%
df3.to_csv('2010_2013.csv')

# %%
df2.to_csv('2014_2017.csv')

# %%
driver.close()
